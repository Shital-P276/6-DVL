# %%
import pandas as pd

# Load the fullGas.csv file into a pandas DataFrame
df = pd.read_csv('/content/fullGas.csv')

print("Original DataFrame Info:")
df.info()
print("\nFirst 5 rows of the original DataFrame:")
display(df.head())
# Out:
# Original DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40494 entries, 0 to 40493
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  40494 non-null  object
#  1   Model                 40273 non-null  object
#  2   Body                  40493 non-null  object
#  3   Mileage_km            40494 non-null  int64
#  4   Price                 40494 non-null  int64
#  5   Year                  38799 non-null  float64
#  6   Country               37902 non-null  object
#  7   Condition             40494 non-null  object
#  8   Fuel_Type             40465 non-null  object
#  9   Fuel_Consumption_l    12773 non-null  float64
#  10  Drivetrain            31860 non-null  object
#  11  Gearbox               40014 non-null  object
#  12  Gears                 25115 non-null  float64
#  13  Power_hp              40494 non-null  int64
#  14  Engine_Size_cc        34564 non-null  float64
#  15  Cylinders             30332 non-null  float64
#  16  Seats                 38697 non-null  float64
#  17  Doors                 39517 non-null  float64
#  18  Color                 37919 non-null  object
#  19  Upholstery            33222 non-null  object
#  20  Full_Service_History  40494 non-null  bool
#  21  Non_Smoker_Vehicle    40494 non-null  bool
#  22  Previous_Owners       22271 non-null  float64
#  23  Seller                40344 non-null  object
#  24  Image_url             40494 non-null  object
# dtypes: bool(2), float64(8), int64(3), object(12)
# memory usage: 7.2+ MB
#
# First 5 rows of the original DataFrame:
#      Make Model     Body  Mileage_km  Price    Year Country Condition  \
# 0  Abarth   595  Compact       98000  16900  2020.0      IT      Used
# 1  Abarth   595    Sedan       91500  12500  2017.0      IT      Used
# 2  Abarth   595  Compact       40000  17990  2015.0      IT      Used
# 3  Abarth   500  Compact      133000   9300  2008.0      IT      Used
# 4  Abarth   595  Compact       61019  14990  2021.0      BE      Used
#
#   Fuel_Type  Fuel_Consumption_l  ... Cylinders Seats  Doors   Color  \
# 0  Gasoline                 6.7  ...       4.0   4.0    3.0   White
# 1  Gasoline                 6.0  ...       4.0   4.0    3.0    Grey
# 2  Gasoline                 6.5  ...       4.0   4.0    3.0  Bronze
# 3  Gasoline                 6.5  ...       4.0   4.0    3.0   Black
# 4  Gasoline                 NaN  ...       4.0   4.0    3.0  Yellow
#
#      Upholstery  Full_Service_History  Non_Smoker_Vehicle  Previous_Owners  \
# 0  Full leather                 False               False              NaN
# 1  Full leather                 False                True              4.0
# 2  Full leather                  True                True              1.0
# 3         Cloth                  True                True              2.0
# 4  Part leather                  True                True              1.0
#
#    Seller                                          Image_url
# 0  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 1  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 2  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 3  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 4  Dealer  https://prod.pictures.autoscout24.net/listing-...
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Data Type Conversion and Feature Extraction
#
# Assuming your dataset contains a 'Date' column (or similar, like 'Timestamp' or 'DateTime'), I will convert it to a datetime object and then extract several time-based features that can be useful for analysis or modeling. If your date column has a different name, please adjust `df['Date']` accordingly.
#
# Extracted features will include: `year`, `month`, `day`, `dayofweek` (0=Monday, 6=Sunday), `dayofyear`, `weekofyear`, `quarter`, and `is_weekend`.

# %% [markdown]
# ### Handling Missing Values
#
# I will check for missing values across all columns and fill numerical columns with their mean. For other data types, you might consider different strategies like mode imputation or dropping rows/columns, depending on the context.

# %%
print("Missing values before handling:")
display(df.isnull().sum()[df.isnull().sum() > 0])

# Fill missing numerical values with the mean of their respective columns
for col in df.select_dtypes(include=['number']).columns:
    if df[col].isnull().any():
        df[col].fillna(df[col].mean(), inplace=True)

print("\nMissing values after handling (numerical columns filled with mean):")
display(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before handling:
# Model                   221
# Body                      1
# Year                   1695
# Country                2592
# Fuel_Type                29
# Fuel_Consumption_l    27721
# Drivetrain             8634
# Gearbox                 480
# Gears                 15379
# Engine_Size_cc         5930
# Cylinders             10162
# Seats                  1797
# Doors                   977
# Color                  2575
# Upholstery             7272
# Previous_Owners       18223
# Seller                  150
# dtype: int64
# Missing values after handling (numerical columns filled with mean):
# /tmp/ipython-input-1766101810.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# Model          221
# Body             1
# Country       2592
# Fuel_Type       29
# Drivetrain    8634
# Gearbox        480
# Color         2575
# Upholstery    7272
# Seller         150
# dtype: int64

# %% [markdown]
# ### Processed Data Overview

# %%
print("DataFrame Info: after processing.")
df.info()
print("\nFirst 5 rows of the processed DataFrame (showing new features):")
display(df.head())
# Out:
# Processed DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40494 entries, 0 to 40493
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  40494 non-null  object
#  1   Model                 40273 non-null  object
#  2   Body                  40493 non-null  object
#  3   Mileage_km            40494 non-null  int64
#  4   Price                 40494 non-null  int64
#  5   Year                  40494 non-null  float64
#  6   Country               37902 non-null  object
#  7   Condition             40494 non-null  object
#  8   Fuel_Type             40465 non-null  object
#  9   Fuel_Consumption_l    40494 non-null  float64
#  10  Drivetrain            31860 non-null  object
#  11  Gearbox               40014 non-null  object
#  12  Gears                 40494 non-null  float64
#  13  Power_hp              40494 non-null  int64
#  14  Engine_Size_cc        40494 non-null  float64
#  15  Cylinders             40494 non-null  float64
#  16  Seats                 40494 non-null  float64
#  17  Doors                 40494 non-null  float64
#  18  Color                 37919 non-null  object
#  19  Upholstery            33222 non-null  object
#  20  Full_Service_History  40494 non-null  bool
#  21  Non_Smoker_Vehicle    40494 non-null  bool
#  22  Previous_Owners       40494 non-null  float64
#  23  Seller                40344 non-null  object
#  24  Image_url             40494 non-null  object
# dtypes: bool(2), float64(8), int64(3), object(12)
# memory usage: 7.2+ MB
#
# First 5 rows of the processed DataFrame (showing new features):
#      Make Model     Body  Mileage_km  Price    Year Country Condition  \
# 0  Abarth   595  Compact       98000  16900  2020.0      IT      Used
# 1  Abarth   595    Sedan       91500  12500  2017.0      IT      Used
# 2  Abarth   595  Compact       40000  17990  2015.0      IT      Used
# 3  Abarth   500  Compact      133000   9300  2008.0      IT      Used
# 4  Abarth   595  Compact       61019  14990  2021.0      BE      Used
#
#   Fuel_Type  Fuel_Consumption_l  ... Cylinders Seats  Doors   Color  \
# 0  Gasoline            6.700000  ...       4.0   4.0    3.0   White
# 1  Gasoline            6.000000  ...       4.0   4.0    3.0    Grey
# 2  Gasoline            6.500000  ...       4.0   4.0    3.0  Bronze
# 3  Gasoline            6.500000  ...       4.0   4.0    3.0   Black
# 4  Gasoline            6.727151  ...       4.0   4.0    3.0  Yellow
#
#      Upholstery  Full_Service_History  Non_Smoker_Vehicle  Previous_Owners  \
# 0  Full leather                 False               False         1.406313
# 1  Full leather                 False                True         4.000000
# 2  Full leather                  True                True         1.000000
# 3         Cloth                  True                True         2.000000
# 4  Part leather                  True                True         1.000000
#
#    Seller                                          Image_url
# 0  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 1  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 2  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 3  Dealer  https://prod.pictures.autoscout24.net/listing-...
# 4  Dealer  https://prod.pictures.autoscout24.net/listing-...
#
# [5 rows x 25 columns]
